# %% [markdown]
# Napisz klasę robot.
#
# Atrybuty: (`5` punktów)
# > nazwa - nazwa robota
#
# > start - współrzędne punktu z którego robot startuje, domyślnie (0,0) (krotka)
#
# > miejsce - współrzędne punktu w którym robot się znajduje (lista)
#
# > moc - ilość energii, którą posiada robot domyślne na strat 9
#
# Metody: (`10,10,5,5 punktów odpowiednio`)
# > instancji
#    -  up - ruch do góry o określoną w argumencie liczbę pól
#    - left - ruch w lewo o określoną  w argumencie liczbę pól
#    - __str__ - informacje o nazwie, pozycji i ilości energii
#    - sprawdz_moc - zgłasza wyjątek gdy moc spadnie do 0 lub jest mmniejsza.
#
#
# Funkcjonalność:
#  > utworzenie instancji klasy robot i wykonanie testów ręcznych lub z wykorzysatniem modułu random pokzaujących, że robot porusza się zmienia się jego moc (w tym ulega doładowaniu) oraz konczy pracę gdy moc jest mniejsza lub równa 0 (`5`)
#
#  > przemierzanie tablicy o wymiarach 8 na 8 zgodnie z regułami:
#         - gdy osiągnie krawędź (górę planszy),  to pojawia się na dole w tej samej kolumnie
#         - gdy osiągnie krawędź (lewy bok), to pojawia się z prawej strony w tym samym wierszu
#
#   > dodanie mocy - gdy robot znajduje się na dowolnym polu pierwszej kolumny (`5`)
#
#   > moc zminiejsza się o ilość przebytych pól
#
#   > obsługa zgłoszonego błędu - moc <=0   (`5`)
#
#
# Klasa powinna zawierać docstirng (styl dowolny) (`5`)
#
# Dodanie setterów, getterów (`+10 punktów`)

# %%
class robot:
    '''Class robot
    
    Klasa nadaje nazwę, miejsce początkowe(domyślnie (0,0)), moc(domyślnie(9)) robota oraz aktualne położenie(domyślnie(0,0)).
    
    zawiera funkcje służące do sterowania robotem oraz __str__ który wypisuje aktualne położenie, moc i nazwę robota.
    '''
    def __init__(self,nazwa,miejsce=[0,0],moc=9,start=(0,0)):
        self.nazwa=nazwa
        self.start=start
        self.miejsce=miejsce
        self.moc=moc
    def up(self,i):
        i2=i

        if self.moc>0:
            while i >0:
                if self.moc>0:
                    self.miejsce[0] = self.miejsce[0]+1
                    if self.miejsce[0]>8:
                        self.miejsce[0]=1
                    
                    self.moc=self.moc-1
                    i-=1
            
                else:
                    print(f'Robot poszedł w górę o {i2-i} pól ')
                    return ' brakuje mocy!'
                    break
            return f'Robot poszedł w górę o {i2} pól '
                
        else:
            return ' brakuje mocy!'

    def left(self,i):
        i2=i
        if self.moc>0:

            while i >0:
                if self.moc>0:
                    self.miejsce[1] = self.miejsce[1]-1
                    if self.miejsce[1]<-8:
                        self.miejsce[1]=-1
                    self.moc=self.moc-1
                    i-=1
                else:
                    print(f'Robot poszedł w lewo o {i2-i} pól ')
                    return ' brakuje mocy!'
                    break
            if self.miejsce[1]==-8:
                self.moc=self.moc+5
            return f'Robot poszedł w lewo o {i2} pól '
        else:
            return ' brakuje mocy!'
    def __str__(self):
        return f'Robot {self.nazwa} znajduje się na {self.miejsce} i ma jeszcze {self.moc} energii'
#     def sprawdz_moc(self):

print(robot1.left(3))
print(robot1)
# Out:
# Robot poszedł w lewo o 3 pól
# Robot Robot1 znajduje się na [0, -3] i ma jeszcze 6 energii

# %%
robot1=robot('Robot1')
def get_nazwa(self):
    return self.nazwa

def get_miejsce(self):
    return self.miejsce  

def get_moc(self):
    return self.get_moc
  
def get_start(self):
    return self.start





def set_nazwa(self,j):
    print("setter")
    if isinstance(j, str):
        self.nazwa=j
    else:
        raise TypeError("Wpisz nazwę typu str")

def set_miejsce(self,j):
    print("setter")
    if isinstance(j, [int,int]):
        self.miejsce=j
    else:
        raise TypeError("Miejsce wpisz jako lista")

def set_moc(self,j):
    print("setter")
    if isinstance(j, int) and j > 0:
        self.moc=j
    else:
        raise TypeError("Moc wpisz typu int oraz mniejsze lub równe 0")

def set_start(self,j):
    print("setter")
    if isinstance(j, (int,int)):
        self.start=j
    else:
        raise TypeError("Start wpisz jako krotka")
